# %%
import pandas as pd
import numpy as np
from dateutil import parser
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %% [markdown]
# 1. Load the dataset using Pandas.
# 2. Display:
# The first 10 rows
# Dataset shape
# Column names and data types
# Summary statistics

# %%
df = pd.read_csv("data/educational_facilities.csv", low_memory=False)
df.head(10)
# Out:
#                  facility_name                         facility_type_display  \
# 0                    CPS SWALI                           Primary school only
# 1           NANA Basic Academy  Primary and Junior Secondary school combined
# 2  L.E.A Primary School Pabeyi                           Primary school only
# 3   L.E.A.PrimarySchoolPagadna                           Primary school only
# 4              Syflora Academy                           Primary school only
# 5           Nomadic Paiko Kore                           Primary school only
# 6                 Nomadic Jayi                           Primary school only
# 7              Nomadic Kutunku                           Primary school only
# 8       Bargada Primary School                           Primary school only
# 9          Macbeth Intl School  Primary and Junior Secondary school combined
#
#   improved_water_supply improved_sanitation chalkboard_each_classroom_yn  \
# 0                  True                True                        False
# 1                 False               False                          NaN
# 2                  True                True                        False
# 3                 False                True                        False
# 4                 False                True                         True
# 5                  True                True                         True
# 6                  True                True                         True
# 7                  True                True                        False
# 8                 False                True                        False
# 9                  True                True                         True
#
#    num_tchrs_with_nce  num_tchr_full_time  num_students_total  \
# 0                 9.0                 9.0               776.0
# 1                 NaN                 NaN                 NaN
# 2                 9.0                11.0               283.0
# 3                 4.0                 5.0               247.0
# 4                 4.0                 8.0                66.0
# 5                 4.0                 6.0               120.0
# 6                 4.0                 4.0               152.0
# 7                 7.0                10.0               245.0
# 8                 4.0                 5.0               181.0
# 9                 3.0                 6.0                80.0
#
#    num_classrms_total phcn_electricity  ...   community     ward  management  \
# 0                12.0            False  ...       Swali        3      public
# 1                 NaN            False  ...       Mpape    Dutse     private
# 2                 9.0            False  ...      Pabeyi     Dobi      public
# 3                 7.0            False  ...     Pagadna     Dobi      public
# 4                10.0             True  ...       Mpape    Dutse     private
# 5                 6.0            False  ...  Paiko Kore    Paiko      public
# 6                 9.0            False  ...        Jayi     Dobi      public
# 7                10.0             True  ...     Kutunku  Kutunku      public
# 8                10.0            False  ...     Bargada    Paiko      public
# 9                 6.0            False  ...     Byazhin  Byazhin     private
#
#       sector   formhub_photo_id  \
# 0  education  1393404015008.jpg
# 1  education  1396960914896.jpg
# 2  education  1397575395444.jpg
# 3  education  1398262573409.jpg
# 4  education  1396959110576.jpg
# 5  education  1398330459520.jpg
# 6  education  1397572115063.jpg
# 7  education  1398345111978.jpg
# 8  education  1398340786686.jpg
# 9  education  1397485980654.jpg
#
#                                              gps  \
# 0                 4.91691036 6.27412844 31.5 5.0
# 1  9.140918333333333 7.496761666666667 697.0 4.5
# 2          9.174855 7.0220616666666675 236.8 5.0
# 3  9.115846666666666 6.962314999999999 216.5 4.4
# 4           9.141155 7.499665000000001 693.2 4.7
# 5           8.99146 7.0096750000000005 170.9 5.0
# 6  9.204203333333334 7.015148333333333 271.4 4.5
# 7  8.934686666666666 7.056360000000001 174.9 4.6
# 8  8.921268333333334 6.959628333333335 161.8 4.3
# 9           9.19196 7.3325966666666655 455.2 3.8
#
#                               survey_id       unique_lga  latitude longitude
# 0  51885096-65a1-4f1f-8c2a-3b11d9ae40bb  bayelsa_yenagoa  4.916910  6.274128
# 1  7f3ea41a-e4cb-41dd-85fc-5fa54c42d09f        fct_bwari  9.140918  7.496762
# 2  56f2e625-ec43-4c39-97a8-d6379dceefa2   fct_gwagwalada  9.174855  7.022062
# 3  2932eda8-64b1-4068-8412-3b2e099062fc   fct_gwagwalada  9.115847  6.962315
# 4  e17acb1e-364a-4a90-9384-0d612bb240c5        fct_bwari  9.141155  7.499665
# 5  28d8fe5a-7a18-4d17-9f64-7ae095eb1c50   fct_gwagwalada  8.991460  7.009675
# 6  31381276-73f9-4e30-acde-bec286919256   fct_gwagwalada  9.204203  7.015148
# 7  76a5fbc9-6723-467a-939d-703a3702ec53   fct_gwagwalada  8.934687  7.056360
# 8  6bd36fb3-704a-49ad-a96a-b25b24af78d3   fct_gwagwalada  8.921268  6.959628
# 9  7e344ad8-c442-4138-a869-6ce98794beaa        fct_bwari  9.191960  7.332597
#
# [10 rows x 28 columns]

# %%
#Data Shape

print(df.shape)
# Out:
# (98667, 28)

# %%
#Column names and data types
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 98667 entries, 0 to 98666
# Data columns (total 28 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   facility_name                 98452 non-null  str
#  1   facility_type_display         97764 non-null  str
#  2   improved_water_supply         98388 non-null  object
#  3   improved_sanitation           98370 non-null  object
#  4   chalkboard_each_classroom_yn  96506 non-null  object
#  5   num_tchrs_with_nce            95137 non-null  float64
#  6   num_tchr_full_time            96503 non-null  float64
#  7   num_students_total            93405 non-null  float64
#  8   num_classrms_total            95375 non-null  float64
#  9   phcn_electricity              98390 non-null  object
#  10  num_toilets_total             95705 non-null  float64
#  11  num_students_male             94292 non-null  float64
#  12  num_students_female           94321 non-null  float64
#  13  num_tchrs_male                94987 non-null  float64
#  14  num_tchrs_female              95348 non-null  float64
#  15  date_of_survey                98667 non-null  str
#  16  education_type                98446 non-null  str
#  17  facility_id                   98667 non-null  str
#  18  community                     98429 non-null  str
#  19  ward                          97896 non-null  str
#  20  management                    97444 non-null  str
#  21  sector                        98667 non-null  str
#  22  formhub_photo_id              98667 non-null  str
#  23  gps                           98667 non-null  str
#  24  survey_id                     98667 non-null  str
#  25  unique_lga                    98666 non-null  str
#  26  latitude                      98667 non-null  float64
#  27  longitude                     98667 non-null  float64
# dtypes: float64(11), object(4), str(13)
# memory usage: 41.3+ MB

# %%
#Summary statistics

df.describe()
# Out:
#        num_tchrs_with_nce  num_tchr_full_time  num_students_total  \
# count        95137.000000        96503.000000        93405.000000
# mean             7.017922           11.666197          335.406306
# std              8.045479           14.033793          343.354223
# min              0.000000            0.000000            0.000000
# 25%              2.000000            4.000000          118.000000
# 50%              5.000000            8.000000          223.000000
# 75%              9.000000           14.000000          419.000000
# max            100.000000          899.000000         2355.000000
#
#        num_classrms_total  num_toilets_total  num_students_male  \
# count        95375.000000       95705.000000       94292.000000
# mean             8.443512           2.546722         187.804628
# std              7.110507           5.768857         257.891030
# min              0.000000           0.000000           0.000000
# 25%              4.000000           0.000000          59.000000
# 50%              6.000000           0.000000         114.000000
# 75%             11.000000           4.000000         220.000000
# max            514.000000         418.000000        7677.000000
#
#        num_students_female  num_tchrs_male  num_tchrs_female      latitude  \
# count         94321.000000    94987.000000      95348.000000  98667.000000
# mean            169.837438        5.723583          5.957985      8.636626
# std             227.880995        6.205914          8.519480      2.403356
# min               0.000000        0.000000          0.000000      4.280918
# 25%              50.000000        2.000000          0.000000      6.671873
# 50%             100.000000        4.000000          3.000000      8.140478
# 75%             200.000000        7.000000          8.000000     10.631606
# max            6689.000000      100.000000        100.000000     13.875585
#
#           longitude
# count  98667.000000
# mean       7.183757
# std        2.353375
# min        2.707594
# 25%        5.327685
# 50%        7.303945
# 75%        8.566094
# max       14.636391

# %%
#Checking for Missing values
# Incorrect data types
# Inconsistent values


df.isnull().sum()
# Out:
# facility_name                    215
# facility_type_display            903
# improved_water_supply            279
# improved_sanitation              297
# chalkboard_each_classroom_yn    2161
# num_tchrs_with_nce              3530
# num_tchr_full_time              2164
# num_students_total              5262
# num_classrms_total              3292
# phcn_electricity                 277
# num_toilets_total               2962
# num_students_male               4375
# num_students_female             4346
# num_tchrs_male                  3680
# num_tchrs_female                3319
# date_of_survey                     0
# education_type                   221
# facility_id                        0
# community                        238
# ward                             771
# management                      1223
# sector                             0
# formhub_photo_id                   0
# gps                                0
# survey_id                          0
# unique_lga                         1
# latitude                           0
# longitude                          0
# dtype: int64

# %%
#Dropping Unused Columns

df = df.drop(columns=['formhub_photo_id', 'sector', 'gps','survey_id'])

df.columns
# Out:
# Index(['facility_name', 'facility_type_display', 'improved_water_supply',
#        'improved_sanitation', 'chalkboard_each_classroom_yn',
#        'num_tchrs_with_nce', 'num_tchr_full_time', 'num_students_total',
#        'num_classrms_total', 'phcn_electricity', 'num_toilets_total',
#        'num_students_male', 'num_students_female', 'num_tchrs_male',
#        'num_tchrs_female', 'date_of_survey', 'education_type', 'facility_id',
#        'community', 'ward', 'management', 'unique_lga', 'latitude',
#        'longitude'],
#       dtype='str')

# %%
df.isnull().sum()
# Out:
# facility_name                    215
# facility_type_display            903
# improved_water_supply            279
# improved_sanitation              297
# chalkboard_each_classroom_yn    2161
# num_tchrs_with_nce              3530
# num_tchr_full_time              2164
# num_students_total              5262
# num_classrms_total              3292
# phcn_electricity                 277
# num_toilets_total               2962
# num_students_male               4375
# num_students_female             4346
# num_tchrs_male                  3680
# num_tchrs_female                3319
# date_of_survey                     0
# education_type                   221
# facility_id                        0
# community                        238
# ward                             771
# management                      1223
# unique_lga                         1
# latitude                           0
# longitude                          0
# dtype: int64

# %%
df.rename(columns={
    'num_tchrs_with_nce': 'NCE_teachers',
    'facility_type_display': 'facility_type',
    'num_students_total': 'total_students',
    'chalkboard_each_classroom_yn': 'chalkboard',
    'num_tchr_full_time': 'full_time_teachers',
    'num_students_total': 'total_student',
    'num_classrms_total': 'total_classrooms',
    'phcn_electricity': 'PHCN_electricity',
    'num_toilets_total': 'total_toilets',
    'num_students_male': 'male_students',
    'num_students_female': 'female_students',
    'num_tchrs_male': 'male_teachers',
    'num_tchrs_female': 'female_teachers',
    'date_of_survey': 'survey_date',
    'unique_lga': 'LGA',
}, inplace=True)



df.columns
# Out:
# Index(['facility_name', 'facility_type', 'improved_water_supply',
#        'improved_sanitation', 'chalkboard', 'NCE_teachers',
#        'full_time_teachers', 'total_student', 'total_classrooms',
#        'PHCN_electricity', 'total_toilets', 'male_students', 'female_students',
#        'male_teachers', 'female_teachers', 'survey_date', 'education_type',
#        'facility_id', 'community', 'ward', 'management', 'LGA', 'latitude',
#        'longitude'],
#       dtype='str')

# %%
df['management'].unique()
# Out:
# <ArrowStringArray>
# ['public', 'private', 'none', 'faith_based', nan]
# Length: 5, dtype: str

# %%
#Handling Inconsistency in Facility Type
df.replace({
    'Primary school only': 'Primary School',
    'Primary Only': 'Primary School',
    'Primary and Junior Secondary school combined': 'Primary & Junior Secondary School',
    'Primary, Junior and Senior Secondary school combined': 'Primary, Junior, & Senior Secondary School',
    'Junior Secondary school only': 'Junior Secondary School',
    "Information not available / Don't know": 'none',
    'Junior and Senior Secondary school combined': 'Junior & Senior Secondary School',
    'Pre-primary and Primary school combined': 'Pre-primary & Primary School',
    'Pre-primary and Primary': 'Pre-primary & Primary School',
    'Primary, Junior, and Senior Secondary': 'Primary, Junior, & Senior Secondary School',
    'Junior and Senior Secondary': 'Junior & Senior Secondary School',
    'Junior Secondary Only': 'Junior Secondary School',
    'Primary and Junior Secondary': 'Primary & Junior Secondary School',
    'Pre-primary Only': 'Pre-primary School',
    'Senior Secondary Only': 'Senior Secondary School'
}, inplace=True)

df['facility_type'].unique()
# Out:
# <ArrowStringArray>
# [                            'Primary School',
#           'Primary & Junior Secondary School',
#  'Primary, Junior, & Senior Secondary School',
#                                        'none',
#                     'Junior Secondary School',
#            'Junior & Senior Secondary School',
#                'Pre-primary & Primary School',
#                                           nan,
#             'Adult, Vocational, or Technical',
#                          'Pre-primary School',
#                     'Senior Secondary School']
# Length: 11, dtype: str

# %% [markdown]
# 2. Perform proper data cleaning using the following steps:
#  Handle Missing Values
#  Decide whether to fill or drop missing values.
#  Justify your choices.
#
# Fix Data Types
# Convert all applicable columns to their proper data types (e.g., object to boolean, object to datetime).

# %%
#Changing none to np.nan

df.replace({'none': np.nan}, inplace=True)

df['management'].unique()
# Out:
# <ArrowStringArray>
# ['public', 'private', nan, 'faith_based']
# Length: 4, dtype: str

# %%
#Dropping all nan

df.dropna(inplace=True)

df.info()
df.isnull().sum()
# Out:
# <class 'pandas.DataFrame'>
# Index: 85771 entries, 0 to 98666
# Data columns (total 24 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   facility_name          85771 non-null  str
#  1   facility_type          85771 non-null  str
#  2   improved_water_supply  85771 non-null  object
#  3   improved_sanitation    85771 non-null  object
#  4   chalkboard             85771 non-null  object
#  5   NCE_teachers           85771 non-null  float64
#  6   full_time_teachers     85771 non-null  float64
#  7   total_student          85771 non-null  float64
#  8   total_classrooms       85771 non-null  float64
#  9   PHCN_electricity       85771 non-null  object
#  10  total_toilets          85771 non-null  float64
#  11  male_students          85771 non-null  float64
#  12  female_students        85771 non-null  float64
#  13  male_teachers          85771 non-null  float64
#  14  female_teachers        85771 non-null  float64
#  15  survey_date            85771 non-null  str
#  16  education_type         85771 non-null  str
#  17  facility_id            85771 non-null  str
#  18  community              85771 non-null  str
#  19  ward                   85771 non-null  str
#  20  management             85771 non-null  str
#  21  LGA                    85771 non-null  str
#  22  latitude               85771 non-null  float64
#  23  longitude              85771 non-null  float64
# dtypes: float64(11), object(4), str(9)
# memory usage: 25.4+ MB
# facility_name            0
# facility_type            0
# improved_water_supply    0
# improved_sanitation      0
# chalkboard               0
# NCE_teachers             0
# full_time_teachers       0
# total_student            0
# total_classrooms         0
# PHCN_electricity         0
# total_toilets            0
# male_students            0
# female_students          0
# male_teachers            0
# female_teachers          0
# survey_date              0
# education_type           0
# facility_id              0
# community                0
# ward                     0
# management               0
# LGA                      0
# latitude                 0
# longitude                0
# dtype: int64

# %%
#handling inconsistency in education type and management
df.replace({
    'integrated': 'Integrated',
    'formal_only': 'Formal',
    'religious_only': 'Religious',
    'dk': 'DK',
    'public': 'Public',
    'private': 'Private',
    'faith_based': 'Faith Based'
    

}, inplace=True)

df['education_type'].unique()
# Out:
# <ArrowStringArray>
# ['Formal', 'Integrated', 'Religious', 'DK', 'Formal Only', 'Religious Only']
# Length: 6, dtype: str

# %%
#Converting object to a boolean

object = ['improved_water_supply', 'improved_sanitation', 'chalkboard', 'PHCN_electricity']
df[object] = (df[object].astype(bool))

df.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 85771 entries, 0 to 98666
# Data columns (total 24 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   facility_name          85771 non-null  str
#  1   facility_type          85771 non-null  str
#  2   improved_water_supply  85771 non-null  bool
#  3   improved_sanitation    85771 non-null  bool
#  4   chalkboard             85771 non-null  bool
#  5   NCE_teachers           85771 non-null  float64
#  6   full_time_teachers     85771 non-null  float64
#  7   total_student          85771 non-null  float64
#  8   total_classrooms       85771 non-null  float64
#  9   PHCN_electricity       85771 non-null  bool
#  10  total_toilets          85771 non-null  float64
#  11  male_students          85771 non-null  float64
#  12  female_students        85771 non-null  float64
#  13  male_teachers          85771 non-null  float64
#  14  female_teachers        85771 non-null  float64
#  15  survey_date            85771 non-null  str
#  16  education_type         85771 non-null  str
#  17  facility_id            85771 non-null  str
#  18  community              85771 non-null  str
#  19  ward                   85771 non-null  str
#  20  management             85771 non-null  str
#  21  LGA                    85771 non-null  str
#  22  latitude               85771 non-null  float64
#  23  longitude              85771 non-null  float64
# dtypes: bool(4), float64(11), str(9)
# memory usage: 22.9 MB

# %%
#Handling date type

df['survey_date'] = pd.to_datetime(df['survey_date'], errors="coerce")

df.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 85771 entries, 0 to 98666
# Data columns (total 24 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   facility_name          85771 non-null  str
#  1   facility_type          85771 non-null  str
#  2   improved_water_supply  85771 non-null  bool
#  3   improved_sanitation    85771 non-null  bool
#  4   chalkboard             85771 non-null  bool
#  5   NCE_teachers           85771 non-null  float64
#  6   full_time_teachers     85771 non-null  float64
#  7   total_student          85771 non-null  float64
#  8   total_classrooms       85771 non-null  float64
#  9   PHCN_electricity       85771 non-null  bool
#  10  total_toilets          85771 non-null  float64
#  11  male_students          85771 non-null  float64
#  12  female_students        85771 non-null  float64
#  13  male_teachers          85771 non-null  float64
#  14  female_teachers        85771 non-null  float64
#  15  survey_date            85771 non-null  datetime64[us]
#  16  education_type         85771 non-null  str
#  17  facility_id            85771 non-null  str
#  18  community              85771 non-null  str
#  19  ward                   85771 non-null  str
#  20  management             85771 non-null  str
#  21  LGA                    85771 non-null  str
#  22  latitude               85771 non-null  float64
#  23  longitude              85771 non-null  float64
# dtypes: bool(4), datetime64[us](1), float64(11), str(8)
# memory usage: 22.1 MB

# %%
#Creating total teachers column
df['total_teachers'] = df['male_teachers'] + df['female_teachers']
df.head()
# Out:
#                  facility_name   facility_type  improved_water_supply  \
# 0                    CPS SWALI  Primary School                   True
# 2  L.E.A Primary School Pabeyi  Primary School                   True
# 3   L.E.A.PrimarySchoolPagadna  Primary School                  False
# 4              Syflora Academy  Primary School                  False
# 5           Nomadic Paiko Kore  Primary School                   True
#
#    improved_sanitation  chalkboard  NCE_teachers  full_time_teachers  \
# 0                 True       False           9.0                 9.0
# 2                 True       False           9.0                11.0
# 3                 True       False           4.0                 5.0
# 4                 True        True           4.0                 8.0
# 5                 True        True           4.0                 6.0
#
#    total_student  total_classrooms  PHCN_electricity  ...  survey_date  \
# 0          776.0              12.0             False  ...   2014-03-04
# 2          283.0               9.0             False  ...   2014-05-02
# 3          247.0               7.0             False  ...   2014-04-25
# 4           66.0              10.0              True  ...   2014-04-25
# 5          120.0               6.0             False  ...   2014-04-25
#
#    education_type  facility_id   community   ward management              LGA  \
# 0          Formal        EIRJK       Swali      3     Public  bayelsa_yenagoa
# 2          Formal        EDJJK      Pabeyi   Dobi     Public   fct_gwagwalada
# 3          Formal        ELOOD     Pagadna   Dobi     Public   fct_gwagwalada
# 4          Formal        EZJOH       Mpape  Dutse    Private        fct_bwari
# 5          Formal        EULMF  Paiko Kore  Paiko     Public   fct_gwagwalada
#
#    latitude longitude total_teachers
# 0  4.916910  6.274128            9.0
# 2  9.174855  7.022062           11.0
# 3  9.115847  6.962315            5.0
# 4  9.141155  7.499665            8.0
# 5  8.991460  7.009675            6.0
#
# [5 rows x 25 columns]

# %%
#Creating total teachers column
# df['total_students'] = df['male_students'] + df['female_students']
# df.head()

# %%
#Creating Student-to-Teacher Ratio Column

df['student_teacher_ratio'] = round(df['total_student'] / df['total_teachers'])
df.head()
# Out:
#                  facility_name   facility_type  improved_water_supply  \
# 0                    CPS SWALI  Primary School                   True
# 2  L.E.A Primary School Pabeyi  Primary School                   True
# 3   L.E.A.PrimarySchoolPagadna  Primary School                  False
# 4              Syflora Academy  Primary School                  False
# 5           Nomadic Paiko Kore  Primary School                   True
#
#    improved_sanitation  chalkboard  NCE_teachers  full_time_teachers  \
# 0                 True       False           9.0                 9.0
# 2                 True       False           9.0                11.0
# 3                 True       False           4.0                 5.0
# 4                 True        True           4.0                 8.0
# 5                 True        True           4.0                 6.0
#
#    total_student  total_classrooms  PHCN_electricity  ...  education_type  \
# 0          776.0              12.0             False  ...          Formal
# 2          283.0               9.0             False  ...          Formal
# 3          247.0               7.0             False  ...          Formal
# 4           66.0              10.0              True  ...          Formal
# 5          120.0               6.0             False  ...          Formal
#
#    facility_id   community   ward  management              LGA  latitude  \
# 0        EIRJK       Swali      3      Public  bayelsa_yenagoa  4.916910
# 2        EDJJK      Pabeyi   Dobi      Public   fct_gwagwalada  9.174855
# 3        ELOOD     Pagadna   Dobi      Public   fct_gwagwalada  9.115847
# 4        EZJOH       Mpape  Dutse     Private        fct_bwari  9.141155
# 5        EULMF  Paiko Kore  Paiko      Public   fct_gwagwalada  8.991460
#
#   longitude total_teachers student_teacher_ratio
# 0  6.274128            9.0                  86.0
# 2  7.022062           11.0                  26.0
# 3  6.962315            5.0                  49.0
# 4  7.499665            8.0                   8.0
# 5  7.009675            6.0                  20.0
#
# [5 rows x 26 columns]

# %%
#Creating State Column

df['states'] = df['LGA'].str.split('_').str[0].str.title()
df.head()
# Out:
#                  facility_name   facility_type  improved_water_supply  \
# 0                    CPS SWALI  Primary School                   True
# 2  L.E.A Primary School Pabeyi  Primary School                   True
# 3   L.E.A.PrimarySchoolPagadna  Primary School                  False
# 4              Syflora Academy  Primary School                  False
# 5           Nomadic Paiko Kore  Primary School                   True
#
#    improved_sanitation  chalkboard  NCE_teachers  full_time_teachers  \
# 0                 True       False           9.0                 9.0
# 2                 True       False           9.0                11.0
# 3                 True       False           4.0                 5.0
# 4                 True        True           4.0                 8.0
# 5                 True        True           4.0                 6.0
#
#    total_student  total_classrooms  PHCN_electricity  ...  facility_id  \
# 0          776.0              12.0             False  ...        EIRJK
# 2          283.0               9.0             False  ...        EDJJK
# 3          247.0               7.0             False  ...        ELOOD
# 4           66.0              10.0              True  ...        EZJOH
# 5          120.0               6.0             False  ...        EULMF
#
#     community   ward  management              LGA  latitude longitude  \
# 0       Swali      3      Public  bayelsa_yenagoa  4.916910  6.274128
# 2      Pabeyi   Dobi      Public   fct_gwagwalada  9.174855  7.022062
# 3     Pagadna   Dobi      Public   fct_gwagwalada  9.115847  6.962315
# 4       Mpape  Dutse     Private        fct_bwari  9.141155  7.499665
# 5  Paiko Kore  Paiko      Public   fct_gwagwalada  8.991460  7.009675
#
#   total_teachers student_teacher_ratio   states
# 0            9.0                  86.0  Bayelsa
# 2           11.0                  26.0      Fct
# 3            5.0                  49.0      Fct
# 4            8.0                   8.0      Fct
# 5            6.0                  20.0      Fct
#
# [5 rows x 27 columns]

# %%
#Facility density by location

df['LGA_facility_density'] = df.groupby('LGA')['facility_name'].transform('count')
df.head()
# Out:
#                  facility_name   facility_type  improved_water_supply  \
# 0                    CPS SWALI  Primary School                   True
# 2  L.E.A Primary School Pabeyi  Primary School                   True
# 3   L.E.A.PrimarySchoolPagadna  Primary School                  False
# 4              Syflora Academy  Primary School                  False
# 5           Nomadic Paiko Kore  Primary School                   True
#
#    improved_sanitation  chalkboard  NCE_teachers  full_time_teachers  \
# 0                 True       False           9.0                 9.0
# 2                 True       False           9.0                11.0
# 3                 True       False           4.0                 5.0
# 4                 True        True           4.0                 8.0
# 5                 True        True           4.0                 6.0
#
#    total_student  total_classrooms  PHCN_electricity  ...   community   ward  \
# 0          776.0              12.0             False  ...       Swali      3
# 2          283.0               9.0             False  ...      Pabeyi   Dobi
# 3          247.0               7.0             False  ...     Pagadna   Dobi
# 4           66.0              10.0              True  ...       Mpape  Dutse
# 5          120.0               6.0             False  ...  Paiko Kore  Paiko
#
#    management              LGA  latitude longitude total_teachers  \
# 0      Public  bayelsa_yenagoa  4.916910  6.274128            9.0
# 2      Public   fct_gwagwalada  9.174855  7.022062           11.0
# 3      Public   fct_gwagwalada  9.115847  6.962315            5.0
# 4     Private        fct_bwari  9.141155  7.499665            8.0
# 5      Public   fct_gwagwalada  8.991460  7.009675            6.0
#
#   student_teacher_ratio   states LGA_facility_density
# 0                  86.0  Bayelsa                  129
# 2                  26.0      Fct                  126
# 3                  49.0      Fct                  126
# 4                   8.0      Fct                  190
# 5                  20.0      Fct                  126
#
# [5 rows x 28 columns]

# %% [markdown]
# Part 3: Exploratory Data Analysis (EDA)
# Answer the following key questions using analysis and supporting visualizations:
# What are the most common types of educational facilities?
# What percentage of schools have:
#     Improved water supply?
#     Improved sanitation?
#     Electricity?
#
# What is the average number of:
#     Students per school?
#     Teachers per school?
#
#
# Compare public vs private schools in terms of:
#     Student population
#     Teacher count
#     Infrastructure availability
#
# Identify states or LGAs with:
#     The highest number of schools
#     The lowest access to electricity and sanitation

# %%
#What are the most common types of educational facilities?

df.groupby('facility_type')['facility_name'].count().sort_values(ascending=False)
# Out:
# facility_type
# Primary School                                39208
# Pre-primary & Primary School                  26135
# Junior & Senior Secondary School               8088
# Junior Secondary School                        6293
# Primary & Junior Secondary School              1614
# Pre-primary School                             1541
# Primary, Junior, & Senior Secondary School     1448
# Senior Secondary School                        1223
# Adult, Vocational, or Technical                 221
# Name: facility_name, dtype: int64

# %%
#What percentage of schools have Improved water supply?

print('Percentage of Schools with Improved Water:', round(df['improved_water_supply'].mean() * 100), 2)
# Out:
# Percentage of Schools with Improved Water: 38 2

# %%
#What percentage of schools have improved sanitation?

print('Percentage of Schools with Improved Sanitaion:', round(df['improved_sanitation'].mean() * 100), 2)
# Out:
# Percentage of Schools with Improved Sanitaion: 46 2

# %%
#What percentage of schools have electricity?

print('Percentage of Schools with Electricity:', round(df['PHCN_electricity'].mean() * 100), 2)
# Out:
# Percentage of Schools with Electricity: 24 2

# %%
#What is the average number of Students per school?

print("Average Student per School:", round(df['total_student'].mean(), 2))
# Out:
# Average Student per School: 337.64

# %%
#What is the average number of Teachers per school?

print("Average Teachers per School:", round(df['total_teachers'].mean(), 2))
# Out:
# Average Teachers per School: 11.42

# %%
#Compare public vs private schools in terms of Student population

df.groupby('management')['total_student'].sum().sort_values(ascending=False)
# Out:
# management
# Public         24673359.0
# Private         3935755.0
# Faith Based      350325.0
# Name: total_student, dtype: float64

# %%
#Compare public vs private schools in terms of Teacher count
df.groupby('management')['total_teachers'].sum().sort_values(ascending=False)
# Out:
# management
# Public         730238.0
# Private        231969.0
# Faith Based     17623.0
# Name: total_teachers, dtype: float64

# %%
#Compare public vs private schools in terms of Infrastructure availability
df.groupby('management')['total_classrooms'].sum().sort_values(ascending=False)
# Out:
# management
# Public         514698.0
# Private        180785.0
# Faith Based     12833.0
# Name: total_classrooms, dtype: float64

# %%
#Identify states with the highest number of schools
df.groupby('states')['facility_name'].count().sort_values(ascending=False).head(10)
# Out:
# states
# Kano       5599
# Kaduna     4447
# Oyo        4316
# Niger      3798
# Benue      3681
# Ogun       3243
# Plateau    3212
# Delta      3141
# Katsina    2945
# Osun       2827
# Name: facility_name, dtype: int64

# %%
#Identify states with the lowest access to electricity and sanitation
df.groupby('states')[['improved_water_supply', 'improved_sanitation']].value_counts().sort_values(ascending=True).head()
# Out:
# states   improved_water_supply  improved_sanitation
# Bayelsa  True                   False                  81
# Fct      True                   False                  83
# Abia     True                   False                  91
# Borno    True                   False                  97
# Bayelsa  False                  True                   98
# Name: count, dtype: int64

# %% [markdown]
# Part 4: Data Visualization
# Create clear and well-labeled visualizations using Plotly. At minimum, include:
#     Bar chart of school types
#     Histogram of student population
#     Boxplot of teacher distribution
#     Pie chart of water and sanitation access
#     Map visualization using latitude and longitude

# %%
#Bar chart of school types

school_bar = df.groupby('facility_type')['facility_name'].count().sort_values(ascending=False)
fig1 = px.bar(
    x=school_bar.values,
    y=school_bar.index,
    title='Type of Schools'

)
fig1.update_layout(xaxis_title='Count', yaxis_title='School Type')
fig1.show()

# %%
#Histogram of student population

fig2 = px.histogram(
    df,
    x='total_student',
    nbins=20,
    title='Student Population'
)
fig2.update_traces(
    marker_line_color='red',
    marker_line_width=1
)
fig2.show()

# %%
#Boxplot of teacher distribution

# sns.boxplot(df['total_teachers'])
# plt.title("Teachers' Distribution")
# plt.show

fig3 = px.box(
    df,
    y='total_teachers',
    title="Teachers' Distribution"
)

fig3.show()

# %%
# Pie chart of water access
water_access = df['improved_water_supply'].value_counts()
fig4 = px.pie(
    values=water_access.values,
    names=water_access.index,
    title='Distribution of Water Access'
)
fig4.show()

# %%
# Pie chart of sanitation access
sanitation_access = df['improved_sanitation'].value_counts()
fig4 = px.pie(
    values=sanitation_access.values,
    names=sanitation_access.index,
    title='Distribution of Sanitation Access'
)
fig4.show()

# %%
#Map visualization using latitude and longitude

cord = ['latitude', 'longitude']
corr = df[cord].corr()

sns.heatmap(corr, annot=True, cmap="vlag", fmt='.2f')

plt.title('Heatmap of the Cordinates')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
#Saving the cleaned data as csv

df.to_csv('data/clean_edu_data.csv', index=False)
